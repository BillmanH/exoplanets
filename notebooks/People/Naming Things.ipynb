# %% [markdown]
# # Procedurally generated names
#
# This will use the names of populations (pops) and celestial objects. It is based on a dataset of city names worldwide
#
# **Note** that this file generates the `syllables.p` that is a part of the repo
#
# I want names that are:
# * Procedurally generated
# * Culturally ambiguous
# * Sound like real words
#
# To do this, I'm going to parse a dataset of cities, and build a model that uses words based on their occurance.

# %%
import pickle
import re

import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.tokenize import SyllableTokenizer


from collections import Counter
import altair as alt

# %%
# # Install the nltk material if you haven't already
# import nltk
# nltk.download('all')

# %%
cities = pd.read_csv("../../data/world-cities.csv")
cities["name"] = cities["name"].str.lower()
cities["country"] = cities["country"].str.lower()


ci = cities["name"].drop_duplicates().str.lower().values
co = cities["country"].drop_duplicates().str.lower().values

ci
# Out:
# array(['les escaldes', 'andorra la vella', 'umm al qaywayn', ...,
#        'beitbridge', 'epworth', 'chitungwiza'], dtype=object)

# %% [markdown]
# Making all of them into a big list of words

# %%
words = pd.concat([pd.DataFrame(ci), pd.DataFrame(co)]).drop_duplicates().values
words = " ".join(words.flatten())
words[:400]
# Out:
# 'les escaldes andorra la vella umm al qaywayn ras al-khaimah khawr fakkān dubai dibba al-fujairah dibba al-hisn sharjah ar ruways al fujayrah al ain ajman adh dhayd abu dhabi zaranj taloqan shīnḏanḏ shibirghān shahrak sar-e pul sang-e chārak aībak rustāq qarqīn qarāwul pul-e khumrī paghmān nahrīn maymana mehtar lām mazār-e sharīf lashkar gāh kushk kunduz khōst khulm khāsh khanabad karukh kandahār k'

# %%
SSP = SyllableTokenizer()

tokens = [SSP.tokenize(token) for token in word_tokenize(words)]
# Out:
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ā'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ī'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ḏ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ō'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ē'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '’'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ë'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ç'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'í'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'á'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'é'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ú'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ó'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ñ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ö'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ə'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ı'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ş'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ğ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'š'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'č'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ž'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ć'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'à'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'è'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'â'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ô'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ŭ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '‘'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ḩ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ã'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ê'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'õ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'î'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ï'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ü'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '1'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '0'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '4'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '2'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '3'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '6'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '9'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '8'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '7'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ů'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ď'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ř'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ý'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ě'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ň'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ß'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ä'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ø'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'æ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'å'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'û'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ţ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ū'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ò'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'œ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ÿ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '5'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ḯ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ő'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ḥ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ẕ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ẖ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '̱'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ṭ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '̄'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '̧'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ð'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ì'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ù'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ŏ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ĭ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ă'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ė'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ḑ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ж'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'е'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'л'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'и'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'н'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'о'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'т'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'а'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'р'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ц'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'с'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'у'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'д'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ч'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ј'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'в'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ш'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'г'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'п'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'к'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'з'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'м'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ż'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '̇'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ś'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ą'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ł'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ń'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ę'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ź'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ș'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ț'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'đ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ľ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ť'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'б'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ũ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ị'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ĩ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ệ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ố'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ủ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ầ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ộ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ỳ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ơ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ạ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ả'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ư'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ế'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ỹ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ằ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ờ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ẩ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ỉ'
#   " assigning as vowel: '{}'".format(c)
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\nltk\tokenize\sonority_sequencing.py:104: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: 'ắ'
#   " assigning as vowel: '{}'".format(c)

# %%
tokens[:10]
# Out:
# [['les'],
#  ['es', 'cal', 'des'],
#  ['an', 'dor', 'ra'],
#  ['la'],
#  ['vel', 'la'],
#  ['umm'],
#  ['al'],
#  ['qay', 'wayn'],
#  ['ras'],
#  ['al', '-', 'khai', 'mah']]

# %% [markdown]
# So you can see the list of lists in the names of cities world wide.

# %%
all_syls = np.concatenate(tokens).ravel()
all_syls
# Out:
# array(['les', 'es', 'cal', ..., 'zim', 'ba', 'bwe'], dtype='<U8')

# %% [markdown]
# Clean up to remove special characters (which may be les inclusive but will prevent errors in unicoding)

# %%
syl = [i for i in all_syls if type(i)==np.str_]
clean_syll = [i for i in syl if re.match("[a-z]+$",i)]

# %%
counts = Counter(clean_syll)
df = pd.DataFrame.from_dict(dict(counts), orient='index', columns=['count'])
df['pct'] = df['count']/(df['count'].sum())
df = df[df['count']>1]
df
# Out:
#         count       pct
# les        85  0.001289
# es         82  0.001244
# cal        39  0.000592
# des        45  0.000683
# an        253  0.003837
# ...       ...       ...
# bloem       2  0.000030
# bwa         2  0.000030
# slands     13  0.000197
# tius        2  0.000030
# blic        5  0.000076
#
# [3270 rows x 2 columns]

# %%
hist = alt.Chart(df).mark_bar().encode(x = alt.X('count',
                                            bin = alt.BinParams(maxbins = 30)),
                                            y = 'count()')
hist
# Out:
# alt.Chart(...)

# %% [markdown]
# pretty long tail. Let's cut that a little more.

# %%
shorter_df = df[df['count']>20]
shorter_df['pct'] = shorter_df['count']/(shorter_df['count'].sum())
shorter_df
# Out:
# C:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          count       pct
# les         85  0.001779
# es          82  0.001716
# cal         39  0.000816
# des         45  0.000942
# an         253  0.005294
# ...        ...       ...
# kiy         56  0.001172
# tsu         63  0.001318
# gorsk       28  0.000586
# heights     35  0.000732
# beach       31  0.000649
#
# [457 rows x 2 columns]

# %%
hist = alt.Chart(shorter_df).mark_bar().encode(x = alt.X('count',
                                            bin = alt.BinParams(maxbins = 30)),
                                            y = 'count()')
hist
# Out:
# alt.Chart(...)

# %% [markdown]
# ## First iteration: Choosing purely randomly.

# %%
# Actual production function
def make_word(n, spaces=True):
    # TODO: Spaces not implemented
    syl = np.random.choice(shorter_df.index.to_list(), n)
    word = "".join(syl)
    return word.capitalize()

# %%
[make_word(3) for word in range(10)]
# Out:
# ['Nerhuling',
#  'Helwalher',
#  'Gaskdro',
#  'Mauviapro',
#  'Landfonay',
#  'Carrezgro',
#  'Turonin',
#  'Fenvavil',
#  'Ziburgua',
#  'Herletche']

# %% [markdown]
# You randomizing the length of the word makes them look prety good.

# %%
[make_word(np.random.choice([1, 2,3])) for word in range(10)]
# Out:
# ['Damti',
#  'May',
#  'Loski',
#  'Rio',
#  'Linglisis',
#  'Pet',
#  'Ter',
#  'Springsrin',
#  'Delhunat',
#  'Neu']

# %% [markdown]
# ## Second Iteration: Using the probability distribution to aid in choosing

# %%
syllables = shorter_df.index.to_list()
syllables_dist = shorter_df['pct'].values

# Actual production function
def make_dist_word(n, spaces=True):
    # TODO: Spaces not implemented
    syl = np.random.choice(syllables, n, p=syllables_dist)
    word = "".join(syl)
    return word.capitalize()

# %%
[make_dist_word(np.random.choice([2,3,4])) for word in range(10)]
# Out:
# ['Zotavorich',
#  'Coli',
#  'Cicama',
#  'Linreno',
#  'Dailiki',
#  'Langnakai',
#  'Tovo',
#  'Chican',
#  'Tate',
#  'Albara']

# %%
[make_word(np.random.choice([2,3,4])) for word in range(10)]
# Out:
# ['Wooddassochar',
#  'Sulsy',
#  'Nebonder',
#  'Yhaberg',
#  'Halheskrasno',
#  'Raykra',
#  'Santko',
#  'Franbarin',
#  'Eljilai',
#  'Eastbermai']

# %% [markdown]
# I'm not sure which I like better so I'll try them both on for a while and make a decsision later.

# %%
pickle.dump(syllables, open("../../data/syllables.p", "wb"))
pickle.dump(syllables_dist, open("../../data/syllables_dist.p", "wb"))

# %% [markdown]
# **Note** that you'll need to move your `.p` files to the `app/creators/specs/` manually as a process control. That way you can review before updating this in prod.
