# %% [markdown]
# # Practicing making gremlin queries
#
# From the [PRACTICAL GREMLIN: An Apache TinkerPop Tutorial](https://www.kelvinlawrence.net/book/PracticalGremlin.html) by **Kelvin R. Lawrence**

# %%
import sys
import numpy as np
import pandas as pd
import altair as alt
sys.path.append('..')
import helpers.dbquery as db
import helpers.functions as f
import yaml, ssl, asyncio
import nb_black

ssl._create_default_https_context = ssl._create_unverified_context
asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
import nest_asyncio
# this is required for running in a Jupyter Notebook. 
nest_asyncio.apply()

# %%
# using some static variables
popID = '4253777177342'
username = 'BillmanLocal2'

# %% [markdown]
# ## 3.1. Introducing Gremlin
# https://www.kelvinlawrence.net/book/PracticalGremlin.html#gremlinintro
#
# ```
# g.V().hasLabel('airport').groupCount().by('country')
# g.V().has('code','AUS').out().out().out().has('code','AGR').path().by('code')
# g.V().has('airport','code','DFW').values()
# ```

# %%
res = db.run_query(f"g.V().hasLabel('pop').groupCount().by('isInFaction')")
pd.DataFrame(res).T
# Out:
#                0
# 3794143165810  3
# 6653752176151  2
# 1227517311167  2
# 6519578400148  3
# 6471846259067  1
# 0876465147511  3
# 3369222775527  3
# 6613533879046  2
# 9883807940485  2
# 9833564464287  3
# 0573461376016  3
# 9484698246542  1
# 4939834578389  3
# 4222061939323  2
# 7220165068620  2
# 3323278109620  4
# 3229062775596  2
# 8124662340858  1
# 8096582192116  3
# 9285140459817  3
# 4597279352126  1

# %%
res = db.run_query(f"g.V().has('username','{username}').out().out().path().by('name')")
pd.DataFrame(res)
# Out:
#           labels                                 objects
# 0   [[], [], []]   [BillmanLocal2, Kerve, BillmanLocal2]
# 1   [[], [], []]   [Gouhillleskin, Kerve, BillmanLocal2]
# 2   [[], [], []]  [Gouhillleskin, Garmaiquaranfe, Kerve]
# 3   [[], [], []]   [Gouhillleskin, Garmaiquaranfe, Fort]
# 4   [[], [], []]        [Conrangu, Kerve, BillmanLocal2]
# ..           ...                                     ...
# 95  [[], [], []]                  [Renna U, Earth, Fort]
# 96  [[], [], []]                [Roysa Ku, Earth, Kerve]
# 97  [[], [], []]                 [Roysa Ku, Earth, Fort]
# 98  [[], [], []]              [Roysa Beam, Earth, Kerve]
# 99  [[], [], []]               [Roysa Beam, Earth, Fort]
#
# [100 rows x 2 columns]

# %%
res = db.run_query(f"g.V().has('faction','name','Geibryan').values()")
res
# Out:
# ['Geibryan', '3794143165810', 1, 'billmanhlaptop', 'faction']

# %%
res = db.run_query(f"g.V().has('faction','name','Geibryan').values('username')")
res
# Out:
# ['billmanhlaptop']

# %%
res = db.run_query(f"g.V().hasNot('username').limit(1)")
res
# Out:
# [{'id': 'd31c5d26-6e6c-4f5c-bad2-2604e48e0f1d',
#   'label': 'planet',
#   'type': 'vertex',
#   'properties': {'pl_name': [{'id': '7a73567c-697c-4866-8076-6d80698aebba',
#      'value': 'PSR B1257+12 c'}],
#    'pl_name.1': [{'id': '8fae4d0f-38c8-4980-8fb4-9291dc60a820',
#      'value': 'PSR B1257+12 c'}],
#    'hostname': [{'id': 'a31e998d-28cc-4448-a437-5e76decf9c32',
#      'value': 'PSR B1257+12'}],
#    'pl_letter': [{'id': '0b94f6c4-cf25-4f39-8e1a-0f4dbd67f589', 'value': 'c'}],
#    'default_flag': [{'id': '9830a6d9-a3ec-4b96-a7ea-b03c48cb4754',
#      'value': '0'}],
#    'sy_snum': [{'id': '2d758c1e-c185-47ed-816f-1f8e6194399e', 'value': '1'}],
#    'sy_pnum': [{'id': 'd396eb59-1b36-4334-8e10-8d1ab3ef2657', 'value': '3'}],
#    'sy_mnum': [{'id': 'e157a267-bae3-4d14-9756-9817455f1859', 'value': '0'}],
#    'cb_flag': [{'id': '1d6b3a11-2d3a-4e54-b0df-3bc3027106c8', 'value': '0'}],
#    'discoverymethod': [{'id': 'fe66dfb3-1899-4e35-9cca-215a3f5bc2e8',
#      'value': 'Pulsar Timing'}],
#    'disc_year': [{'id': '07497472-4273-4edd-9228-4921ffaf18bb',
#      'value': '1992'}],
#    'disc_locale': [{'id': '673570db-b748-447e-ace7-3e64c0e7fc7c',
#      'value': 'Ground'}],
#    'disc_facility': [{'id': '64f9b542-99f6-4ede-ab28-adcc2faf085f',
#      'value': 'Arecibo Observatory'}],
#    'soltype': [{'id': 'ccc4d064-845b-4787-9565-69a57cdb9d82',
#      'value': 'Published Confirmed'}],
#    'pl_controv_flag': [{'id': '59e73027-3183-4163-9e46-2620aa70663f',
#      'value': '0'}],
#    'pl_refname': [{'id': '5773613e-4323-4e3e-902f-dd489de18e01',
#      'value': '<a refstr=WOLSZCZAN_ET_AL__1992 href=https://ui.adsabs.harvard.edu/abs/1992Natur.355..145W/abstract target=ref> Wolszczan et al. 1992 </a>'}],
#    'pl_orbper': [{'id': 'cef88e04-f0ce-45eb-8a97-85f07f51adb7',
#      'value': '66.563'}],
#    'pl_orbpererr1': [{'id': 'ebbf3a21-e85c-4b71-8c33-19c097a3bcc5',
#      'value': '0.009'}],
#    'pl_orbpererr2': [{'id': 'dbb9ee70-87f7-4b92-9baf-c60d166f30f9',
#      'value': '-0.009'}],
#    'pl_orbperlim': [{'id': '4bdd8f92-e515-4bd2-a400-8503d3b3ee30',
#      'value': '0.0'}],
#    'pl_orbsmax': [{'id': '4a6b8c00-3043-45bb-93cc-e6f38e106177',
#      'value': '0.36'}],
#    'pl_orbsmaxlim': [{'id': '0b2daa6b-deef-4462-bbdb-e09e7528402e',
#      'value': '0.0'}],
#    'pl_orbeccen': [{'id': 'b3996351-0c8f-4bb3-a515-262dad3e600a',
#      'value': '0.022'}],
#    'pl_orbeccenerr1': [{'id': '2a234132-ccfb-464b-8c4b-9a8e61cebc37',
#      'value': '0.007'}],
#    'pl_orbeccenerr2': [{'id': 'ffb31d21-19f2-4787-85d9-7a410271ff36',
#      'value': '-0.007'}],
#    'pl_orbeccenlim': [{'id': 'bea59f2f-a4bd-4843-a8be-5ed6ac2786c3',
#      'value': '0.0'}],
#    'ttv_flag': [{'id': '4286da02-6525-42d3-9dee-eb3ae1bf3d37', 'value': '0'}],
#    'pl_orbtper': [{'id': '5f5f1cd8-4c35-4c18-9434-5e673ef0b659',
#      'value': '2448105.3'}],
#    'pl_orbtpererr1': [{'id': 'fc447f2f-3d05-4c53-8330-4e492869f403',
#      'value': '1.0'}],
#    'pl_orbtpererr2': [{'id': '0973088d-3633-4bd4-b41c-e0397590fd00',
#      'value': '-1.0'}],
#    'pl_orbtperlim': [{'id': '0ce474bd-c2de-4322-97f9-207c6a49b1de',
#      'value': '0.0'}],
#    'st_refname': [{'id': '72d6ef8d-2b62-45c9-8a5d-9d648dcb9078',
#      'value': '<a refstr=WOLSZCZAN_ET_AL__1992 href=https://ui.adsabs.harvard.edu/abs/1992Natur.355..145W/abstract target=ref> Wolszczan et al. 1992 </a>'}],
#    'st_age': [{'id': '45f4f727-5378-4e0b-a0f9-644107c5e727', 'value': '0.8'}],
#    'st_agelim': [{'id': '0f92109b-0fa9-4567-bb64-a4046ab89efc',
#      'value': '0.0'}],
#    'sy_refname': [{'id': '6306c900-0f0b-4f72-8f60-8518c6815efe',
#      'value': '<a refstr=KONACKI_AND_WOLSZCZAN_2003 href=https://ui.adsabs.harvard.edu/abs/2003ApJ...591L.147K/abstract target=ref> Konacki and Wolszczan 2003 </a>'}],
#    'rastr': [{'id': '97518be0-acbd-4d27-964b-e49aaaffe3f9',
#      'value': '13h00m03.58s'}],
#    'ra': [{'id': 'cf5584db-b7f3-4a7a-bf0b-eaf715c2228c',
#      'value': '195.0149029'}],
#    'decstr': [{'id': 'b2d38ef3-e612-4175-aca5-d138da63cb6b',
#      'value': '+12d40m56.5s'}],
#    'dec': [{'id': '14b96b57-a206-4c75-86f7-94f14fd95deb',
#      'value': '12.6823534'}],
#    'glat': [{'id': 'f6de684a-cee0-4144-a85e-d5e990427025',
#      'value': '75.413648'}],
#    'glon': [{'id': 'f769bc2a-7a05-43e1-aaff-0fa7828d58b2',
#      'value': '311.30969'}],
#    'elat': [{'id': '686fd223-d846-4f5a-ab09-8e8881894ec0',
#      'value': '17.575802'}],
#    'elon': [{'id': '64fc7f0e-df81-403d-8704-64c2685e67e7',
#      'value': '188.722087'}],
#    'sy_dist': [{'id': '28a9609c-ce26-4a20-a046-0cf3ec4b8040',
#      'value': '600.0'}],
#    'sy_disterr1': [{'id': 'a0b93e89-1468-4f3b-8408-8d65c55fefd8',
#      'value': '100.0'}],
#    'sy_disterr2': [{'id': '5bd298c9-f4b0-40ba-ad2a-6f4988a02479',
#      'value': '-100.0'}],
#    'rowupdate': [{'id': '109aca6c-921e-4ab9-96fe-0184133ae6f0',
#      'value': '2015-04-30'}],
#    'pl_pubdate': [{'id': '43868716-83a8-439a-a5aa-be271e04ea2a',
#      'value': '1992-01'}],
#    'releasedate': [{'id': 'd024ebec-cf0b-4dbb-93fb-e03fba113b88',
#      'value': '2015-04-30'}],
#    'objid': [{'id': 'd31c5d26-6e6c-4f5c-bad2-2604e48e0f1d|objid',
#      'value': '51196769'}]}}]

# %% [markdown]
# ### 3.2.3. Counting things

# %%
res = db.run_query(f"g.V().hasLabel('account').count()")
res
# Out:
# [9]

# %%
res = db.run_query(f"g.V().hasLabel('pop').outE('desires').count()")
res
# Out:
# [661]

# %% [markdown]
# ### 3.2.4. Counting groups of things

# %%
res = db.run_query(f"g.V().groupCount().by(label)")
res
# Out:
# [{'planet': 4421,
#   'system': 3248,
#   'example': 4,
#   'objective': 5,
#   'account': 9,
#   'star': 9,
#   'moon': 216,
#   'species': 7,
#   'pop': 49,
#   'faction': 21,
#   'form': 6,
#   'time': 1,
#   'action': 8}]

# %%
res = db.run_query(f"g.E().groupCount().by(label)")
res
# Out:
# [{'isInSystem': 9022,
#   'isExample': 1,
#   'orbits': 270,
#   'belongsToUser': 9,
#   'isInFaction': 46,
#   'isOfSpecies': 49,
#   'enhabits': 45,
#   'desires': 661,
#   'requestedSystem': 4}]

# %%
res = db.run_query(f"g.V().hasLabel('pop').groupCount().by('username')")
res
# Out:
# [{'billmanhlaptop': 7,
#   'billmanh4': 7,
#   'BillmanLocal': 7,
#   'william.jeffrey.harding@gmail.com': 7,
#   'explorer': 7,
#   'BillmanLocal2': 7,
#   'Billmanserver': 7}]

# %%
res = db.run_query(f"g.V().hasLabel('planet').has('username','BillmanLocal2').limit(1).valuemap()")
res
# Out:
# [{'class': ['gas'],
#   'name': ['Garmaiquaranfe'],
#   'objid': ['2622750356280'],
#   'mass': [125.4727],
#   'radius': [9.8151],
#   'orbitsDistance': [19],
#   'orbitsId': ['4845567259981'],
#   'orbitsName': ['Fort'],
#   'isSupportsLife': ['False'],
#   'isPopulated': ['False'],
#   'username': ['BillmanLocal2'],
#   'objtype': ['planet']}]

# %%
res = db.run_query(f"g.V().hasLabel('pop').groupCount().by('username').select('billmanh4','billmanh4')")
res
# Out:
# ---------------------------------------------------------------------------
# GremlinServerError                        Traceback (most recent call last)
# <ipython-input-30-4d8e48f9d5ad> in <module>
# ----> 1 res = db.run_query(f"g.V().hasLabel('pop').groupCount().by('username').select('billmanh4','billmanh4')")
#       2 res
#
# c:\Users\william.harding\Documents\repos\exoplanets\notebooks\helpers\dbquery.py in run_query(query)
#      34     c = get_client()
#      35     callback = c.submitAsync(query)
# ---> 36     res = callback.result().all().result()
#      37     c.close()
#      38     return res
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\gremlin_python\driver\resultset.py in cb(f)
#      88         def cb(f):
#      89             try:
# ---> 90                 f.result()
#      91             except Exception as e:
#      92                 future.set_exception(e)
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\concurrent\futures\_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\gremlin_python\driver\connection.py in _receive(self)
#      81             while True:
#      82                 data = self._transport.read()
# ---> 83                 status_code = self._protocol.data_received(data, self._results)
#      84                 if status_code != 206:
#      85                     break
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\gremlin_python\driver\protocol.py in data_received(self, message, results_dict)
#     116             data = self._transport.read()
#     117             # Allow for auth handshake with multiple steps
# --> 118             return self.data_received(data, results_dict)
#     119         elif status_code == 204:
#     120             result_set.stream.put_nowait([])
#
# c:\Users\william.harding\anaconda3\envs\exoplanets\lib\site-packages\gremlin_python\driver\protocol.py in data_received(self, message, results_dict)
#     129         else:
#     130             del results_dict[request_id]
# --> 131             raise GremlinServerError(message['status'])
#     132
#     133     def _kerberos_received(self, message):
#
# GremlinServerError: 500:
#
# ActivityId : de1584e1-f549-4834-bd47-ad9d1f1f80ff
# ExceptionType : ArgumentException
# ExceptionMessage : An unknown error occurred while processing this request. If the issue persists, please contact Azure Support: http://aka.ms/azure-support
# 	HResult : 0x80070057

# %% [markdown]
# ## 3.3. Starting to walk the graph

# %%
res = db.run_query(f"g.V().has('planet','isSupportsLife','True').out().values(label,'name')")
res
# Out:
# ['system',
#  'Tsiywiykher',
#  'star',
#  '',
#  'system',
#  '',
#  'star',
#  'Zathoubruns',
#  'system',
#  'Consknell',
#  'star',
#  'Tees',
#  'system',
#  'Skikdzhahakqi',
#  'star',
#  'Roohaqchuns',
#  'system',
#  'Tiancnoanbhart',
#  'star',
#  'Bud',
#  'system',
#  'Svitra',
#  'star',
#  'Jelczgyisaur',
#  'system',
#  'Roysal',
#  'star',
#  'Sau',
#  'system',
#  'Kerve',
#  'star',
#  'Fort',
#  'system',
#  'Milweconwo',
#  'star',
#  'Hay']

# %%
res = db.run_query(f"g.V().has('planet','isSupportsLife','True').outE().groupCount().by(label)")
res
# Out:
# [{'isInSystem': 9, 'orbits': 9}]

# %% [markdown]
# Planets that support life orbit which objects

# %%
res = db.run_query(f"g.V().has('planet','isSupportsLife','True').out('orbits').values('name')")
res
# Out:
# ['',
#  'Zathoubruns',
#  'Tees',
#  'Roohaqchuns',
#  'Bud',
#  'Jelczgyisaur',
#  'Sau',
#  'Fort',
#  'Hay']

# %% [markdown]
# Which objects orbit planets that support life

# %%
res = db.run_query(f"g.V().has('planet','isSupportsLife','False').in('orbits').values('name')")
res
# Out:
# ['Inflansnul',
#  'Hiedric',
#  'Saghdeis',
#  'Saultvoortbutz',
#  'Zansktrowsab',
#  'Laytrichbrua',
#  'Kamp',
#  'Taysmahlsman',
#  'Brawheatksihaar',
#  'Geejaa',
#  'Ripdelf',
#  'Klungnealorsul',
#  '',
#  'Zierswhigles',
#  'Pruduc',
#  'Paz',
#  'Palmlushnhoch',
#  'Kidrarstrezhus',
#  'Nhonaff',
#  'Suamanj',
#  'Brildorp',
#  'Bruckfimsklisobsloch',
#  'Hrweigoz',
#  'Vuewiongryz',
#  'Giers',
#  'Mtsenskku',
#  'Tsuodfreyluzsant',
#  'Cheikhhworthrickhlong',
#  'Fnalous',
#  'Corkbel',
#  'Lill',
#  'Cagnerdhansk',
#  'Warmnancwayq',
#  'Greshrodams',
#  'Ngumzimpitts',
#  'Kiahtinsklesz',
#  'Tufshimgiang',
#  'Bawsboentlis',
#  'Tlovluch',
#  '',
#  'Keocquixguz',
#  'Corbryngling',
#  'Shelxaulkav',
#  'Heidgar',
#  'Jerhamsloo',
#  'Fastcil',
#  'Ukhdnis',
#  'Yingzliy',
#  'Mbal',
#  'Phakmys',
#  'Laotem',
#  'Pomplun',
#  'Huttntunjuif',
#  'Nielovskkyatell',
#  'Sles',
#  'Kurskoohlac',
#  'Hinzychzgierz',
#  'Poynaisix',
#  'Kweksrustsig',
#  'Kushkborz',
#  'Diosjang',
#  'Pietcienhyns',
#  'Firslaaschowc',
#  'Zhongpriygid',
#  'Tzincel',
#  'Tlaxburgh',
#  'Rocksmitc',
#  'Csi',
#  'Raalgningszen',
#  'Menzweesp',
#  'Dorcdutqeshmbnoyview',
#  'Heibloisquet',
#  'Hribstsindigkelkchon',
#  'Koffdea',
#  'Melsshahriu',
#  'Trahsnocknche',
#  'Vamhamn',
#  'Titweereang',
#  'Kwitkumb',
#  'Chalcfreefay',
#  'Westcdmondstsinhans',
#  'Tinsnorthhornc',
#  'Tarskkoot',
#  'Longnyts',
#  '',
#  'Bnoyguancvny',
#  'Kuhquatbaallahn',
#  'Laangeylya',
#  'Amphmuk',
#  'Penbraupryswens',
#  'Kezkongsgnorpenn',
#  'Voatual',
#  'Miinuuk',
#  'Wautelnaalst',
#  'Affhnuleut',
#  'Kiomqiubryantdraa',
#  'Apschopfpeak',
#  'Heeschhnyychatjon',
#  'Zha',
#  'Kachdoncklus',
#  'Noandreirzhevqing',
#  'Psonbnyk',
#  'Gmingcro',
#  'Ros',
#  'Laonzewcakzmir',
#  'Neath',
#  'Rikleebong',
#  'Hardwayndviewhmun',
#  'Revselc',
#  'Gedguanz',
#  'Schroefahtal',
#  'Schobrand',
#  'Zahn',
#  'Mieskiy',
#  'Dajfighcheondmon',
#  'Coishtoonrykuu',
#  'Hresil',
#  'Malspru',
#  'Pruszcznolds',
#  'Hraknien',
#  'Pua',
#  'Crans',
#  'Crimirbep',
#  'Kretletskfers',
#  'Tikcnhonhu',
#  'Lefdniehres',
#  'Feidzyr',
#  'Meikdykbern',
#  'Dwijlewcaa',
#  'Wischgraphongch',
#  'Naurmaurtyan',
#  'Oelgliang',
#  'Vreuxkiev',
#  'Tsovskshiggraf',
#  'Frastlas',
#  'Fahrnnajneal',
#  'Pexgoldschyn',
#  'Thaygarr',
#  'Henfoum',
#  'Jidletskquin',
#  'Vaugcelsmold',
#  'Changsaid',
#  'Sleydeyskessk',
#  'Cacmitbrai',
#  'Hunri',
#  'Sanhesnio',
#  'Chaquaeslam',
#  'Tro',
#  'Balon',
#  'Vicas',
#  'Warnin',
#  'Civo',
#  'Lecanwi',
#  'Nypeta',
#  'Gon',
#  'Tilgengra',
#  'Teinsal',
#  'Hinportby',
#  'Carroy',
#  'Huagarnasren',
#  'Wesbi',
#  'Covarlar',
#  'Qa',
#  'Kas',
#  'Yeselbay',
#  'Herou',
#  'Liarou',
#  'Lou',
#  'Conrangu',
#  'Gouhillleskin',
#  'Bentra',
#  'Mostu',
#  '',
#  'Dypestber',
#  'Gro',
#  'Bre',
#  'Oufermes',
#  'Tarren',
#  'Brekreisdes',
#  'Roy',
#  'Trobosonrat',
#  'Newrerezlyjiang',
#  'Piapurbia',
#  'Dro',
#  'Fe',
#  'Rangvo',
#  'Col',
#  'Rondota',
#  'Anunvia',
#  'Baslank',
#  'Naytil',
#  'Lifieldchi',
#  'Richley',
#  'Piavebil',
#  'Snolo',
#  'Garhil',
#  'Zoneuyo',
#  'May',
#  'Hui',
#  'Riefaan',
#  'Diahui',
#  'Kinbudes',
#  'Nin',
#  'Furam',
#  'Aymorbang',
#  'Gorsklambor',
#  'Newtor',
#  'Puerhaskayher',
#  'Ken',
#  'Doneast',
#  'Dorfmis',
#  'Layrasreku',
#  'Newinnorth',
#  'Yerei',
#  'Diayolaubilya',
#  'Richesboten']

# %% [markdown]
# Which object that orbit clas G stars have planets that are habitable

# %%
res = db.run_query(f"g.V().has('star','class','G').in('orbits').has('isSupportsLife','True').values('name')")
res
# Out:
# ['Earth',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Earth']

# %%
res = db.run_query(f"g.V().has('star','class','G').outE().inV().path()")

# %% [markdown]
# returned is a list of paths, with the objects in them. Each item in the list is a list of size three

# %%
res[0]['objects']
# Out:
# [{'id': '7a9e3f2e-ce4c-4c8e-afef-43ee15557591',
#   'label': 'star',
#   'type': 'vertex',
#   'properties': {'class': [{'id': 'c2c2c059-8652-4f9c-a4c5-0e4cfcbe2e1d',
#      'value': 'G'}],
#    'radius': [{'id': '44896827-da04-4832-90a4-ca3ccba10f0f', 'value': 106}],
#    'name': [{'id': '56f788f9-c312-4f20-9b4a-cd4c4ec13688', 'value': ''}],
#    'objid': [{'id': '7a9e3f2e-ce4c-4c8e-afef-43ee15557591|objid',
#      'value': '7725805562058'}],
#    'username': [{'id': 'acc80266-dd1c-480c-a7dc-0e41bf498cec',
#      'value': 'billmanhlaptop'}],
#    'objtype': [{'id': '0d34bc38-df08-4b29-b97d-802340e46288',
#      'value': 'star'}]}},
#  {'id': '937cdef6-1d7d-482c-b861-0b1f5a4e2433',
#   'label': 'isInSystem',
#   'type': 'edge',
#   'inVLabel': 'system',
#   'outVLabel': 'star',
#   'inV': 'bda86e90-9e05-4b66-8471-beab94f6c817',
#   'outV': '7a9e3f2e-ce4c-4c8e-afef-43ee15557591',
#   'properties': {'username': 'billmanhlaptop'}},
#  {'id': 'bda86e90-9e05-4b66-8471-beab94f6c817',
#   'label': 'system',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '401384a2-e241-485b-8ca2-af497f703eed',
#      'value': 'Tsiywiykher'}],
#    'objid': [{'id': 'bda86e90-9e05-4b66-8471-beab94f6c817|objid',
#      'value': '7452486453159'}],
#    'username': [{'id': '3ac30edc-8a92-4afb-8788-66c1a777a907',
#      'value': 'billmanhlaptop'}],
#    'objtype': [{'id': '8b980571-b006-4c67-ad4d-ac1eb8e698a2',
#      'value': 'system'}]}}]

# %%
[len(i['objects']) for i in res]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3]

# %% [markdown]
# You can also filter on specific values to get a cleaner dataset. use `values('name','radius').fold()` to get a tiny list of items.

# %%
res = db.run_query(f"g.V().has('star','class','G').as('star').outE().as('link').inV().as('system').path().by(values('name','radius').fold()).by(label).by('name')")
res
# Out:
# [{'labels': [['star'], ['link'], ['system']],
#   'objects': [['', 106], 'isInSystem', 'Tsiywiykher']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Zathoubruns', 106], 'isInSystem', '']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Tees', 106], 'isInSystem', 'Consknell']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Roohaqchuns', 106], 'isInSystem', 'Skikdzhahakqi']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Bud', 106], 'isInSystem', 'Tiancnoanbhart']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Jelczgyisaur', 106], 'isInSystem', 'Svitra']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Sau', 106], 'isInSystem', 'Roysal']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Fort', 106], 'isInSystem', 'Kerve']},
#  {'labels': [['star'], ['link'], ['system']],
#   'objects': [['Hay', 106], 'isInSystem', 'Milweconwo']}]

# %% [markdown]
# ## 3.3.5. Using as, select and project to refer to traversal steps

# %%
res = db.run_query(f"g.V().has('class','G').as('Star').in().has('isSupportsLife','True').as('Planet').select('Star','Planet')")
res
# Out:
# [{'Star': {'id': '7a9e3f2e-ce4c-4c8e-afef-43ee15557591',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': 'c2c2c059-8652-4f9c-a4c5-0e4cfcbe2e1d',
#       'value': 'G'}],
#     'radius': [{'id': '44896827-da04-4832-90a4-ca3ccba10f0f', 'value': 106}],
#     'name': [{'id': '56f788f9-c312-4f20-9b4a-cd4c4ec13688', 'value': ''}],
#     'objid': [{'id': '7a9e3f2e-ce4c-4c8e-afef-43ee15557591|objid',
#       'value': '7725805562058'}],
#     'username': [{'id': 'acc80266-dd1c-480c-a7dc-0e41bf498cec',
#       'value': 'billmanhlaptop'}],
#     'objtype': [{'id': '0d34bc38-df08-4b29-b97d-802340e46288',
#       'value': 'star'}]}},
#   'Planet': {'id': '1d4a23cc-5751-4367-bd3f-990e4d3ff22e',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'c6949f31-867f-4ec7-99dd-0b8da55996d9',
#       'value': 'True'}],
#     'class': [{'id': '2e74ea9f-bdd9-4598-ab6d-38b7e9781945',
#       'value': 'terrestrial'}],
#     'name': [{'id': 'f97c359e-0173-43dc-95f1-16eae249e5f9', 'value': 'Earth'}],
#     'objid': [{'id': '1d4a23cc-5751-4367-bd3f-990e4d3ff22e|objid',
#       'value': '5596978223811'}],
#     'mass': [{'id': 'dfaa7cbe-0414-4476-9b89-1bdca8a26e6f', 'value': 0.5715}],
#     'radius': [{'id': '53ac0e93-ec60-461f-9fed-1276718b7531',
#       'value': 0.8395}],
#     'orbitsDistance': [{'id': '70c53e34-5b36-4f9e-9d88-dd0ecd77fe02',
#       'value': 4}],
#     'orbitsId': [{'id': '17c8f91a-4d8f-4ca2-990c-56744c1bc9da',
#       'value': '7725805562058'}],
#     'orbitsName': [{'id': 'caf2235e-69a8-4a25-8658-8ecb554d0caa',
#       'value': ''}],
#     'isPopulated': [{'id': 'd4a18ac8-7086-4bc0-9025-676ca477c6e3',
#       'value': 'True'}],
#     'isHomeworld': [{'id': 'ef9badc2-190f-418a-8b4e-246845782d05',
#       'value': 'True'}],
#     'username': [{'id': 'fe03d2c8-c813-4c9e-942f-d039b838e907',
#       'value': 'billmanhlaptop'}],
#     'objtype': [{'id': '2b3e613f-4cdc-48c4-913d-35a1ee29b1db',
#       'value': 'planet'}]}}},
#  {'Star': {'id': 'f378ac7b-ac56-4c50-9eda-c2cd5426a648',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '259eeb99-4d01-4708-92b1-6701cff6a0af',
#       'value': 'G'}],
#     'radius': [{'id': '20ca998b-92da-4f78-ba1b-2b506ef43647', 'value': 106}],
#     'name': [{'id': 'bb1ecaf9-e763-45d3-ba9e-6b2637883234',
#       'value': 'Zathoubruns'}],
#     'objid': [{'id': 'f378ac7b-ac56-4c50-9eda-c2cd5426a648|objid',
#       'value': '4624324586241'}],
#     'username': [{'id': '1388c597-c71a-495d-9602-269dd9b6db93',
#       'value': 'userbill'}],
#     'objtype': [{'id': '9f455239-259f-4ce8-93d5-de479538f0d7',
#       'value': 'star'}]}},
#   'Planet': {'id': '6eb5025a-b5f8-473c-9ac6-4fa9801e8a51',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'f8b26b1f-fa9d-4f59-982b-e22782be9513',
#       'value': 'True'}],
#     'class': [{'id': 'e582d55b-1750-4ea5-b6f4-d8d184914e6b',
#       'value': 'terrestrial'}],
#     'name': [{'id': '39d45f5b-c8cd-44f2-acd6-d65d3c3c954b', 'value': 'Earth'}],
#     'objid': [{'id': '6eb5025a-b5f8-473c-9ac6-4fa9801e8a51|objid',
#       'value': '1281249220790'}],
#     'mass': [{'id': '9a922bf3-4bbc-47c2-ab37-45ecff8722eb', 'value': 0.6776}],
#     'radius': [{'id': 'efd8a347-6fe7-4156-be5f-7e462a648754',
#       'value': 0.6061}],
#     'orbitsDistance': [{'id': '3180ed3c-1317-4e2d-8e88-07e613735b22',
#       'value': 1}],
#     'orbitsId': [{'id': '7a877f58-3d75-442f-bd41-6b9440501140',
#       'value': '4624324586241'}],
#     'orbitsName': [{'id': '6830df08-447a-4bef-9d9b-518db8a16475',
#       'value': 'Zathoubruns'}],
#     'isPopulated': [{'id': 'd07c20f9-0c99-4967-bdef-fc2da9017a26',
#       'value': 'True'}],
#     'isHomeworld': [{'id': '5c173843-9881-4b7b-be1a-66c4405d3683',
#       'value': 'True'}],
#     'username': [{'id': '722abacc-c2b2-41e4-a8e3-81cd327f4a82',
#       'value': 'userbill'}],
#     'objtype': [{'id': '3307562b-769f-4a80-ba4d-63e0a801f520',
#       'value': 'planet'}]}}},
#  {'Star': {'id': 'a7fd7844-a357-4092-9074-a37f4b59fd0e',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '17a60ac6-9f53-452a-9556-b4ffbf2f9454',
#       'value': 'G'}],
#     'radius': [{'id': 'df3f5ccd-b2bc-416e-bc19-a95a87e7f3af', 'value': 106}],
#     'name': [{'id': '121a6fd2-5679-468d-90ec-0ab2777dc5c7', 'value': 'Tees'}],
#     'objid': [{'id': 'a7fd7844-a357-4092-9074-a37f4b59fd0e|objid',
#       'value': '7502163201384'}],
#     'username': [{'id': 'fcfb5532-6921-4ee7-a205-d28be59e99b5',
#       'value': 'billmanh4'}],
#     'objtype': [{'id': 'f365cf54-f586-42a7-8658-18a2fb8a9bce',
#       'value': 'star'}]}},
#   'Planet': {'id': '13032efe-4d9b-43e5-8bd9-38b3d372c44b',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'd633d25f-a7a9-4965-b48b-c6b9bace6050',
#       'value': 'True'}],
#     'class': [{'id': '28ee4bb6-ff45-4c74-af72-c41c4363674b',
#       'value': 'terrestrial'}],
#     'name': [{'id': '43734bf8-e368-456e-ba76-48e6c8900a39', 'value': 'Earth'}],
#     'objid': [{'id': '13032efe-4d9b-43e5-8bd9-38b3d372c44b|objid',
#       'value': '3535970015503'}],
#     'mass': [{'id': '72035767-8d9a-450b-931b-b0967b38bde5', 'value': 0.8087}],
#     'radius': [{'id': 'fc4b2ee9-a2c0-48e1-bf36-f0b470620e73',
#       'value': 0.6392}],
#     'orbitsDistance': [{'id': '7640b11c-3c8e-4909-aa41-c63d7a370e2e',
#       'value': 2}],
#     'orbitsId': [{'id': '7be2e660-c4a6-4947-962e-4de586b2d166',
#       'value': '7502163201384'}],
#     'orbitsName': [{'id': '6f293578-fa0e-40a2-9b54-01ca697cae48',
#       'value': 'Tees'}],
#     'isPopulated': [{'id': 'cc3efa31-f24c-481f-b49f-2d5f5117f097',
#       'value': 'True'}],
#     'isHomeworld': [{'id': 'f88e5785-5ec9-45ec-8a95-da8ed2ab3e9d',
#       'value': 'True'}],
#     'username': [{'id': 'da82b71f-24ac-4a5a-ba51-92453836bb48',
#       'value': 'billmanh4'}],
#     'objtype': [{'id': '1d480b3b-6a96-4846-98f4-e849a932901b',
#       'value': 'planet'}]}}},
#  {'Star': {'id': '6462fc39-b610-43fe-8279-2cea2c9ca2f0',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': 'c04b38db-0f97-44e2-9ac0-291d7eaf2e13',
#       'value': 'G'}],
#     'radius': [{'id': 'fc022d37-9175-468f-83df-b94baff7e963', 'value': 106}],
#     'name': [{'id': 'de070ebd-1d85-4029-a3f1-66a18621ed83',
#       'value': 'Roohaqchuns'}],
#     'objid': [{'id': '6462fc39-b610-43fe-8279-2cea2c9ca2f0|objid',
#       'value': '2545015797009'}],
#     'username': [{'id': '2614b4bc-29e1-45b0-a987-d61fc8d0341a',
#       'value': 'Billmanh'}],
#     'objtype': [{'id': '35e0456f-df1c-4779-b72b-b3e55c2b716f',
#       'value': 'star'}]}},
#   'Planet': {'id': '0abc737f-06ce-43e7-965b-373e8a096dff',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': '61563549-03f5-418b-8b48-5d2401047d29',
#       'value': 'True'}],
#     'class': [{'id': 'c794e821-7b08-491a-a7b9-0f04a45457e9',
#       'value': 'terrestrial'}],
#     'name': [{'id': 'f2cf988a-b953-492c-995a-d61f3cbc4512', 'value': 'Earth'}],
#     'objid': [{'id': '0abc737f-06ce-43e7-965b-373e8a096dff|objid',
#       'value': '2500643532261'}],
#     'mass': [{'id': '9e9566c1-b67f-4f7f-87f3-b39d367cbc91', 'value': 0.66}],
#     'radius': [{'id': 'd3fc9609-187c-4e1b-be3a-ca0045dd0de1', 'value': 0.92}],
#     'orbitsDistance': [{'id': '5b279672-dadf-40cf-bbff-71557e82610a',
#       'value': 2}],
#     'orbitsId': [{'id': '5c743958-33f8-4ba9-933f-d5a589d240a9',
#       'value': '2545015797009'}],
#     'orbitsName': [{'id': 'e5edf522-615d-4207-92f7-6decced517a3',
#       'value': 'Roohaqchuns'}],
#     'isPopulated': [{'id': 'be38f8ba-d5d4-4515-be01-beabda88e91f',
#       'value': 'True'}],
#     'isHomeworld': [{'id': 'e8f9659f-3af5-4426-9863-14218c4d24a8',
#       'value': 'True'}],
#     'username': [{'id': '187c98c1-d27b-4a00-bc1f-568b18681147',
#       'value': 'Billmanh'}],
#     'objtype': [{'id': '44fb0e12-ed9c-4305-8752-e868ad489124',
#       'value': 'planet'}]}}},
#  {'Star': {'id': '9f24eee0-f06a-4bb1-855c-4e764e4bbb30',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '04df939d-adca-4705-9e37-0c39fe3b1ae3',
#       'value': 'G'}],
#     'radius': [{'id': 'd17fe65e-d27c-47c3-8d11-7e5534e71cef', 'value': 106}],
#     'name': [{'id': '58646e50-bb45-4d66-82b3-db548cdbe9ae', 'value': 'Bud'}],
#     'objid': [{'id': '9f24eee0-f06a-4bb1-855c-4e764e4bbb30|objid',
#       'value': '6837045385784'}],
#     'username': [{'id': '7c1c9f78-eca3-4ff2-b4ea-e0bc0f1c338a',
#       'value': 'BillmanLocal'}],
#     'objtype': [{'id': '804e0922-5007-4df5-b736-666eeee7be26',
#       'value': 'star'}]}},
#   'Planet': {'id': 'c817cb0f-380f-4f32-ae9e-0bb5d6c70a26',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'efb5bdbf-f208-418f-bc73-d0a71f11aae5',
#       'value': 'True'}],
#     'class': [{'id': '63df5a18-61e1-40b2-b1af-d187eea40fb3',
#       'value': 'terrestrial'}],
#     'name': [{'id': '75d5042e-8a4c-444f-a6a0-ad0b3b80cdd8', 'value': 'Earth'}],
#     'objid': [{'id': 'c817cb0f-380f-4f32-ae9e-0bb5d6c70a26|objid',
#       'value': '2711868081060'}],
#     'mass': [{'id': 'bd281c9a-789d-48a1-9a00-54379fa8f892', 'value': 0.7289}],
#     'radius': [{'id': '9957cb22-3371-4aa6-958a-1fe0ab7d9cd6',
#       'value': 1.1949}],
#     'orbitsDistance': [{'id': 'f4cf6c72-051b-4157-a550-a1a47f3b2e64',
#       'value': 1}],
#     'orbitsId': [{'id': 'e8ea4cd9-e52b-430d-8164-4d3f2486b710',
#       'value': '6837045385784'}],
#     'orbitsName': [{'id': 'e9c9b1da-9c41-4666-9b64-48543b668027',
#       'value': 'Bud'}],
#     'isPopulated': [{'id': 'feb2f09c-f759-4eb9-a750-2f970109cc1f',
#       'value': 'True'}],
#     'isHomeworld': [{'id': 'd0a68fb8-216c-4f4d-a065-5399a1506b77',
#       'value': 'True'}],
#     'username': [{'id': '686ff246-9415-441b-888a-57afb96e8923',
#       'value': 'BillmanLocal'}],
#     'objtype': [{'id': '1304bdd1-bbb1-4f18-aba9-11d5e43fe9df',
#       'value': 'planet'}]}}},
#  {'Star': {'id': '86629b6d-c5f1-4b7d-9c90-158b4c6f23c2',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '1e0fb166-23ea-40fc-a2e2-8b60edc346a8',
#       'value': 'G'}],
#     'radius': [{'id': 'ef147a69-726e-46eb-8b4f-76c2998b2c0f', 'value': 106}],
#     'name': [{'id': '3a4f1b87-1093-461d-8b14-d7da610d1749',
#       'value': 'Jelczgyisaur'}],
#     'objid': [{'id': '86629b6d-c5f1-4b7d-9c90-158b4c6f23c2|objid',
#       'value': '2558366890520'}],
#     'username': [{'id': 'd3586737-011f-4559-94f0-86a831486c83',
#       'value': 'william.jeffrey.harding@gmail.com'}],
#     'objtype': [{'id': 'f45183ae-fd86-454d-9e34-9bd0cd2ef4a3',
#       'value': 'star'}]}},
#   'Planet': {'id': 'f478c928-01c8-498b-b1cb-afc29e53308e',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'ded06aab-48c5-45b8-9c3f-39c195cf4d5f',
#       'value': 'True'}],
#     'class': [{'id': 'cdc4e68f-d111-4a2e-8309-b196faefb742',
#       'value': 'terrestrial'}],
#     'name': [{'id': '498dfe43-1cdb-4afd-b41d-ee234b292373', 'value': 'Earth'}],
#     'objid': [{'id': 'f478c928-01c8-498b-b1cb-afc29e53308e|objid',
#       'value': '3725978767878'}],
#     'mass': [{'id': '3b46a9df-1b99-4bda-9fc7-d65acd7ff3fa', 'value': 0.4001}],
#     'radius': [{'id': '4b24623f-4278-48bc-93d9-e152c4d2e6bb',
#       'value': 1.0357}],
#     'orbitsDistance': [{'id': 'd6a570c4-8771-4f3a-8b82-56043db23844',
#       'value': 2}],
#     'orbitsId': [{'id': 'ad58ee8e-2f85-4371-a210-6b52bd9a814d',
#       'value': '2558366890520'}],
#     'orbitsName': [{'id': '7d9be915-5b46-4d76-8889-2480ee598870',
#       'value': 'Jelczgyisaur'}],
#     'isPopulated': [{'id': 'a21de64e-aefc-431a-a363-b62a990b5d59',
#       'value': 'True'}],
#     'isHomeworld': [{'id': '5af93c4e-96b9-4118-ad83-9db407951b93',
#       'value': 'True'}],
#     'username': [{'id': '01dfaa74-6e7d-4659-8f15-a14a3fbc9173',
#       'value': 'william.jeffrey.harding@gmail.com'}],
#     'objtype': [{'id': '618ecf25-3187-4d8f-9a19-eef31b106dfb',
#       'value': 'planet'}]}}},
#  {'Star': {'id': '76333501-969d-442c-a3bf-baffb8e9826a',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '4408047d-a870-47e9-b8fd-27d3334b8337',
#       'value': 'G'}],
#     'radius': [{'id': 'f9e061fc-7c38-47fa-b2d4-fccee10d7f2d', 'value': 106}],
#     'name': [{'id': '28efa734-aa2c-4808-9d34-e4375b5916b5', 'value': 'Sau'}],
#     'objid': [{'id': '76333501-969d-442c-a3bf-baffb8e9826a|objid',
#       'value': '5875551699273'}],
#     'username': [{'id': '70f546bd-67c9-4786-8219-bf11f1898dae',
#       'value': 'explorer'}],
#     'objtype': [{'id': '2c8b7159-c8e2-409c-862c-85b183be54ec',
#       'value': 'star'}]}},
#   'Planet': {'id': '7855c349-da19-4bf1-a627-fd29e66c2460',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': '565a464e-8a6d-4e8b-ac86-c41f47de03cd',
#       'value': 'True'}],
#     'class': [{'id': '63981cac-cb03-4614-9df2-0c816c18e662',
#       'value': 'terrestrial'}],
#     'name': [{'id': 'fafdd3c5-b6fe-420e-9375-e882ef9e4277', 'value': 'Earth'}],
#     'objid': [{'id': '7855c349-da19-4bf1-a627-fd29e66c2460|objid',
#       'value': '2921294995657'}],
#     'mass': [{'id': '80b9a933-ac81-4ea9-9040-cb4dc869b04c', 'value': 0.3194}],
#     'radius': [{'id': '19652c2d-a70c-4091-94ec-01d4b46d7c55',
#       'value': 0.5441}],
#     'orbitsDistance': [{'id': '1cc4f211-5d8f-47b8-85e9-8059420f72b1',
#       'value': 1}],
#     'orbitsId': [{'id': 'ebbf2088-7ce9-4676-935a-5f93da1a0458',
#       'value': '5875551699273'}],
#     'orbitsName': [{'id': '456b8484-3be7-477f-a9d0-aa6627d961fb',
#       'value': 'Sau'}],
#     'isPopulated': [{'id': '146137db-5ddc-4bcf-82f9-bede7407d704',
#       'value': 'True'}],
#     'isHomeworld': [{'id': '2dc06c0e-35e9-4204-86ea-ac325b69d70e',
#       'value': 'True'}],
#     'username': [{'id': 'bc331a2b-8598-442c-bce3-e169161bf106',
#       'value': 'explorer'}],
#     'objtype': [{'id': 'fd5a3856-d9fe-40ce-a21f-cbda03b4e265',
#       'value': 'planet'}]}}},
#  {'Star': {'id': '685236d2-59a7-4dce-8f62-c61b4efe77ac',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': 'd8dcb11e-e852-4a5d-ac16-de0c0216ef97',
#       'value': 'G'}],
#     'radius': [{'id': '24309309-a643-4636-b8fa-af611d78e380', 'value': 106}],
#     'name': [{'id': 'b2e1f721-e69e-4de1-95f4-4179151ef0b0', 'value': 'Fort'}],
#     'objid': [{'id': '685236d2-59a7-4dce-8f62-c61b4efe77ac|objid',
#       'value': '4845567259981'}],
#     'username': [{'id': '1fc9a6ac-0ded-4ec9-97a3-9f46fc2575a4',
#       'value': 'BillmanLocal2'}],
#     'objtype': [{'id': '6339a8c7-d00d-4415-8b25-074f3cfc7648',
#       'value': 'star'}]}},
#   'Planet': {'id': '127a6ed7-794c-44de-83cd-71b703fa2d22',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': 'e7d7e3fb-cbaa-4f31-abb0-f76c77efde58',
#       'value': 'True'}],
#     'class': [{'id': '50f0b054-1066-4b44-9ed0-282ab4617ff3',
#       'value': 'terrestrial'}],
#     'name': [{'id': 'a1246da8-05dd-44df-8925-9d3718d31bfa', 'value': 'Earth'}],
#     'objid': [{'id': '127a6ed7-794c-44de-83cd-71b703fa2d22|objid',
#       'value': '3177950515048'}],
#     'mass': [{'id': 'b47bc5fd-afe9-4366-a22d-f85d752efb97', 'value': 0.9984}],
#     'radius': [{'id': '3881e110-b197-4dba-9d4d-078528605f4f',
#       'value': 0.7849}],
#     'orbitsDistance': [{'id': '2dccbac4-8d1c-4522-8fc1-0ec80e01f2a2',
#       'value': 0}],
#     'orbitsId': [{'id': 'c366fcf7-5231-4a7f-839a-dd9122360676',
#       'value': '4845567259981'}],
#     'orbitsName': [{'id': 'fd979158-ad0a-447f-9424-6013b7ba6aac',
#       'value': 'Fort'}],
#     'isPopulated': [{'id': '24443346-46b8-4e73-8550-75edefbffd1a',
#       'value': 'True'}],
#     'isHomeworld': [{'id': '8c9154a2-42f9-4908-a559-68b768539859',
#       'value': 'True'}],
#     'username': [{'id': 'f9d8b144-4709-450a-9259-519e0e885ab2',
#       'value': 'BillmanLocal2'}],
#     'objtype': [{'id': '232310db-bd30-4cc8-83f5-43201b0de86c',
#       'value': 'planet'}]}}},
#  {'Star': {'id': 'abbe3878-3b26-4474-88f1-1c37de427614',
#    'label': 'star',
#    'type': 'vertex',
#    'properties': {'class': [{'id': '7c27ec65-c303-461a-9883-57d44aa4f2f8',
#       'value': 'G'}],
#     'radius': [{'id': 'e4b96e0f-be59-4967-a017-4b656094d343', 'value': 106}],
#     'name': [{'id': '26e04358-7509-497e-a044-6368cef58124', 'value': 'Hay'}],
#     'objid': [{'id': 'abbe3878-3b26-4474-88f1-1c37de427614|objid',
#       'value': '4038439448968'}],
#     'username': [{'id': '67ac3ad7-2704-46c0-a490-8f24feb8623d',
#       'value': 'Billmanserver'}],
#     'objtype': [{'id': '29aee13f-e8a3-488c-86ea-f197ef7eaa87',
#       'value': 'star'}]}},
#   'Planet': {'id': '1cfaf36f-4267-4550-83a7-745ab2ce20e6',
#    'label': 'planet',
#    'type': 'vertex',
#    'properties': {'isSupportsLife': [{'id': '42f72f7c-82d5-44fa-9199-b7ed64d782b7',
#       'value': 'True'}],
#     'class': [{'id': '6348d42b-4334-4d5e-aa35-c3e813035029',
#       'value': 'terrestrial'}],
#     'name': [{'id': 'a0e4ac41-0a5d-4db2-8686-d0bf4f334523', 'value': 'Earth'}],
#     'objid': [{'id': '1cfaf36f-4267-4550-83a7-745ab2ce20e6|objid',
#       'value': '6798305662239'}],
#     'mass': [{'id': '56337950-a5c5-4d86-b54b-83881acfb737', 'value': 0.6267}],
#     'radius': [{'id': '8134e69e-5dd6-4ff3-a95f-327e123f8f1d',
#       'value': 0.4344}],
#     'orbitsDistance': [{'id': 'd8b1a12f-cd49-444e-9fc6-ae9456cb569f',
#       'value': 1}],
#     'orbitsId': [{'id': '99e01cf2-fa22-4ae3-81b3-c8330fb8e1c4',
#       'value': '4038439448968'}],
#     'orbitsName': [{'id': '11e0bf74-88da-4dc7-92d4-d30d242b7bb7',
#       'value': 'Hay'}],
#     'isPopulated': [{'id': '1541bf16-7e85-42f7-8a49-b69837b62a50',
#       'value': 'True'}],
#     'isHomeworld': [{'id': 'b1eecfee-e6ea-4960-a706-cc83376acf08',
#       'value': 'True'}],
#     'username': [{'id': '59a28585-b209-418c-b3a5-bb13b1c98def',
#       'value': 'Billmanserver'}],
#     'objtype': [{'id': '184f25c5-77c7-479a-905f-db7d586637bc',
#       'value': 'planet'}]}}}]
