# %% [markdown]
# # Using Notebooks as tests
#
# The logic of this game is very complicated. to make it easy to analyse I've built some systems that allow you to troubleshoot quickly and look under the hood.

# %%
import numpy as np
import pandas as pd

import sys, os, yaml, ssl, asyncio
import altair as alt

# mapping to the modules that make the app
sys.path.insert(0, "../..")
sys.path.insert(0, "../../app")
sys.path.insert(0, "..")

# %%
from helpers import test_queries
from app.connectors.cmdb_graph import CosmosdbClient

ssl._create_default_https_context = ssl._create_unverified_context
asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
import nest_asyncio

# this is required for running in a Jupyter Notebook.
nest_asyncio.apply()

c = CosmosdbClient()

# %%
df = test_queries.get_pops(c,'BillmanLocal2')
df
# Out:
#                               name          objid  conformity  literacy
# 0              Shitianewlia Pecbia  1392740103248       0.606     0.265  \
# 1      Shitianewlia Hiaportcharlis  9922156506749       0.680     0.312
# 2                  Shitianewlia Zi  0894561131236       0.622     0.360
# 3                 Woanggal Shakuwi  4097489117670       0.678     0.457
# 4                     Woanggal Lon  3356491698696       0.700     0.394
# 5                     Woanggal Kas  1759158331704       0.709     0.455
# 6          Shitianewlia Gidongrang  3413748712870       0.624     0.374
# 7          Shitianewlia Pecbiarang  8953226925403       0.538     0.199
# 8               Shitianewlia Zicen  7199585478992       0.594     0.307
# 9              Woanggal Shakuwigui  6500296863192       0.628     0.552
# 10                 Woanggal Lonker  3303279520942       0.709     0.455
# 11   Shitianewlia Hiaportcharliska  2410674601046       0.694     0.284
# 12                 Woanggal Lonfen  7678009968476       0.611     0.492
# 13     Shitianewlia Gidongrangbach  0068888796350       0.587     0.287
# 14          Shitianewlia Pecbiahor  7397086652679       0.547     0.212
# 15  Shitianewlia Hiaportcharlisbad  8243771062883       0.758     0.302
# 16             Woanggal Shakuwisil  4951091416473       0.669     0.495
# 17                 Woanggal Londia  5600189710534       0.687     0.427
# 18                 Woanggal Kasgio  5914933764749       0.637     0.438
# 19      Shitianewlia Gidongranglar  7973116893681       0.722     0.361
# 20   Shitianewlia Hiaportcharlissy  7046151039892       0.588     0.253
# 21              Shitianewlia Zitre  9965458062188       0.606     0.280
# 22             Woanggal Shakuwisur  9105999742462       0.754     0.434
# 23                Woanggal Lonrang  1194406329096       0.669     0.433
# 24                 Woanggal Kasgor  5747361062484       0.777     0.363
# 25      Shitianewlia Gidongrangang  8408549527176       0.559     0.279
#
#     aggression  constitution  health           isIn  industry  wealth
# 0        0.652         0.394    0.70  6219407155821    0.5230  0.3940  \
# 1        0.657         0.300    0.70  6219407155821    0.4785  0.3952
# 2        0.588         0.311    0.70  6219407155821    0.4495  0.4048
# 3        0.515         0.418    0.70  3712738152632    0.4665  0.4618
# 4        0.616         0.325    0.70  3712738152632    0.4705  0.4322
# 5        0.661         0.351    0.70  3712738152632    0.5060  0.4805
# 6        0.541         0.292    0.70  6219407155821    0.4165  0.3952
# 7        0.559         0.449    0.42  6219407155821    0.3140  0.2910
# 8        0.559         0.317    0.42  6219407155821    0.2700  0.1900
# 9        0.520         0.384    0.42  3712738152632    0.2800  0.2910
# 10       0.583         0.400    0.42  3712738152632    0.2820  0.3340
# 11       0.751         0.303    0.42  6219407155821    0.2870  0.2480
# 12       0.657         0.381    0.42  3712738152632    0.2820  0.3380
# 13       0.482         0.220    0.42  6219407155821    0.2500  0.3260
# 14       0.627         0.304    0.42  6219407155821    0.3140  0.3350
# 15       0.744         0.370    0.42  6219407155821    0.2870  0.2070
# 16       0.493         0.420    0.42  3712738152632    0.2800  0.2230
# 17       0.555         0.305    0.42  3712738152632    0.2820  0.2280
# 18       0.677         0.304    0.42  3712738152632    0.3040  0.3500
# 19       0.551         0.262    0.42  6219407155821    0.2500  0.2840
# 20       0.708         0.232    0.42  6219407155821    0.2870  0.2280
# 21       0.543         0.402    0.42  6219407155821    0.2700  0.1510
# 22       0.424         0.428    0.42  3712738152632    0.2800  0.2230
# 23       0.529         0.244    0.42  3712738152632    0.2820  0.1960
# 24       0.689         0.396    0.42  3712738152632    0.3040  0.2170
# 25       0.620         0.223    0.42  6219407155821    0.2500  0.2750
#
#     factionLoyalty isIdle       username objtype             id
# 0            0.554   true  BillmanLocal2     pop  1392740103248
# 1            0.704   true  BillmanLocal2     pop  9922156506749
# 2            0.596   true  BillmanLocal2     pop  0894561131236
# 3            0.592   true  BillmanLocal2     pop  4097489117670
# 4            0.686   true  BillmanLocal2     pop  3356491698696
# 5            0.723   true  BillmanLocal2     pop  1759158331704
# 6            0.713   true  BillmanLocal2     pop  3413748712870
# 7            0.506   true  BillmanLocal2     pop  8953226925403
# 8            0.667   true  BillmanLocal2     pop  7199585478992
# 9            0.516   true  BillmanLocal2     pop  6500296863192
# 10           0.766   true  BillmanLocal2     pop  3303279520942
# 11           0.675   true  BillmanLocal2     pop  2410674601046
# 12           0.652   true  BillmanLocal2     pop  7678009968476
# 13           0.676   true  BillmanLocal2     pop  0068888796350
# 14           0.576   true  BillmanLocal2     pop  7397086652679
# 15           0.749   true  BillmanLocal2     pop  8243771062883
# 16           0.497   true  BillmanLocal2     pop  4951091416473
# 17           0.639   true  BillmanLocal2     pop  5600189710534
# 18           0.799   true  BillmanLocal2     pop  5914933764749
# 19           0.801   true  BillmanLocal2     pop  7973116893681
# 20           0.793   true  BillmanLocal2     pop  7046151039892
# 21           0.618   true  BillmanLocal2     pop  9965458062188
# 22           0.612   true  BillmanLocal2     pop  9105999742462
# 23           0.680   true  BillmanLocal2     pop  1194406329096
# 24           0.658   true  BillmanLocal2     pop  5747361062484
# 25           0.709   true  BillmanLocal2     pop  8408549527176

# %%
pop = test_queries.get_random_pop(c,'BillmanLocal2')
pop
# Out:
# {'name': 'Shitianewlia Zitre',
#  'objid': '9965458062188',
#  'conformity': 0.606,
#  'literacy': 0.28,
#  'aggression': 0.543,
#  'constitution': 0.402,
#  'health': 0.42,
#  'isIn': '6219407155821',
#  'industry': 0.27,
#  'wealth': 0.151,
#  'factionLoyalty': 0.618,
#  'isIdle': 'true',
#  'username': 'BillmanLocal2',
#  'objtype': 'pop',
#  'id': '9965458062188'}
